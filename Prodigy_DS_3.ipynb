# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('customer churn.csv')

# %%
df.head(20)
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0     KS             128        415  382-4657         no        yes
# 1     OH             107        415  371-7191         no        yes
# 2     NJ             137        415  358-1921         no         no
# 3     OH              84        408  375-9999        yes         no
# 4     OK              75        415  330-6626        yes         no
# 5     AL             118        510  391-8027        yes         no
# 6     MA             121        510  355-9993         no        yes
# 7     MO             147        415  329-9001        yes         no
# 8     LA             117        408  335-4719         no         no
# 9     WV             141        415  330-8173        yes        yes
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# ...

# %%
data = df.drop(['State', 'Area Code', 'Phone', 'VMail Message', 'Day Calls'], axis=1)
data.head()
# Out:
#    Account Length Int'l Plan VMail Plan  Day Mins  Day Charge  Eve Mins  \
# 0             128         no        yes     265.1       45.07     197.4
# 1             107         no        yes     161.6       27.47     195.5
# 2             137         no         no     243.4       41.38     121.2
# 3              84        yes         no     299.4       50.90      61.9
# 4              75        yes         no     166.7       28.34     148.3
#
#    Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0         99       16.78       244.7           91         11.01       10.0
# 1        103       16.62       254.4          103         11.45       13.7
# 2        110       10.30       162.6          104          7.32       12.2
# 3         88        5.26       196.9           89          8.86        6.6
# 4        122       12.61       186.9          121          8.41       10.1
#
#    Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Account Length    0
# Int'l Plan        0
# VMail Plan        0
# Day Mins          0
# Day Charge        0
# Eve Mins          0
# Eve Calls         0
# Eve Charge        0
# Night Mins        0
# Night Calls       0
# Night Charge      0
# Intl Mins         0
# Intl Calls        0
# Intl Charge       0
# CustServ Calls    0
# Churn?            0
# dtype: int64

# %%
data.shape
# Out:
# (3333, 16)

# %%
import pandas as pd

# ... (other code) ...

# Convert "Churn?" column to boolean type
data["Churn?"] = data["Churn?"].map({"False": False, "True": True})

threshold_balance = data["CustServ Calls"].mean()
threshold_active = data["Churn?"].mean()

def create_purchase_label(row):
    # Access the 'CustServ Calls' column using the correct name
    if row['Churn?'] > threshold_active and row['CustServ Calls'] > threshold_balance:
        return 1
    else:
        return 0

# %%
data['PurchaseLabel'] = data.apply(create_purchase_label, axis=1)

# %%
print(data[['CustServ Calls', 'Churn?', 'PurchaseLabel']])
# Out:
#       CustServ Calls Churn?  PurchaseLabel
# 0                  1    NaN              0
# 1                  1    NaN              0
# 2                  0    NaN              0
# 3                  2    NaN              0
# 4                  3    NaN              0
# ...              ...    ...            ...
# 3328               2    NaN              0
# 3329               3    NaN              0
# 3330               2    NaN              0
# 3331               2    NaN              0
# 3332               0    NaN              0
#
# [3333 rows x 3 columns]

# %%
(data['CustServ Calls']).sum()
# Out:
# 5209

# %%
y = data['CustServ Calls']
x = data.drop(['CustServ Calls'] , axis=1 )

# %%
x.head()
# Out:
#    Account Length Int'l Plan VMail Plan  Day Mins  Day Charge  Eve Mins  \
# 0             128         no        yes     265.1       45.07     197.4
# 1             107         no        yes     161.6       27.47     195.5
# 2             137         no         no     243.4       41.38     121.2
# 3              84        yes         no     299.4       50.90      61.9
# 4              75        yes         no     166.7       28.34     148.3
#
#    Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0         99       16.78       244.7           91         11.01       10.0
# 1        103       16.62       254.4          103         11.45       13.7
# 2        110       10.30       162.6          104          7.32       12.2
# 3         88        5.26       196.9           89          8.86        6.6
# 4        122       12.61       186.9          121          8.41       10.1
#
#    Intl Calls  Intl Charge Churn?  PurchaseLabel
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    2
# 4    3
# Name: CustServ Calls, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=42)

# %%
clf = DecisionTreeClassifier(random_state=42)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# Assuming 'x' is your DataFrame with categorical features
categorical_features = x.select_dtypes(include=['object']).columns

# Create a LabelEncoder object
encoder = LabelEncoder()

# Iterate over categorical features and transform them
for feature in categorical_features:
    x[feature] = encoder.fit_transform(x[feature])

# Now you can split the data and fit the model
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=42)
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.25107112253641817

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.24      0.26      0.25       235
#            1       0.37      0.34      0.36       433
#            2       0.21      0.23      0.22       255
#            3       0.14      0.14      0.14       150
#            4       0.10      0.10      0.10        63
#            5       0.00      0.00      0.00        23
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00         3
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.25      1167
#    macro avg       0.11      0.11      0.11      1167
# weighted avg       0.25      0.25      0.25      1167
# ...

# %%
from sklearn.tree import export_graphviz
import graphviz

# Get unique class labels from your target variable 'y'
class_names = [str(val) for val in y.unique()]

# Use the unique class labels in export_graphviz
dot_data = export_graphviz(clf, out_file=None,
                            feature_names=x.columns,
                            class_names=class_names,  # Changed line
                            filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("decision_tree")
# Out:
# 'decision_tree.pdf'
